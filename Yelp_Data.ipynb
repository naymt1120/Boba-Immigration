# %%
from yelpapi import YelpAPI
import requests
import pandas as pd
from flatten_json import flatten
import json, csv

# %%
api_key = "GCiF6c8mCXxkB4ciWJHurhTzetmItbH0nderuBPJLsJIBCfPc9S3PSJzilWOIgB5rktDdvfuDAJOx9lA5IHqMqfdJue0w8lFlVs2rofvj9gHvIPHDosFo2epXazDW3Yx"
yelp_api = YelpAPI(api_key)

# %%
#Note:

#max radius = 40000
#categories
#sort_by = best_match
#term = "drink"
#categories = bubbletea

# %%
results_boba = yelp_api.search_query(latitude=34.0522, longitude=-118.2437, radius=40000, sort_by='best_match', categories = "bubbletea")
results_boba
# Out:
# {'businesses': [{'id': '-hC4S9XrBFWp2iOstaJTBA',
#    'alias': 'twinkle-brown-sugar-los-angeles-2',
#    'name': 'Twinkle Brown Sugar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8xTPtXXboAArEBi74WIzSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twinkle-brown-sugar-los-angeles-2?adjust_creative=dA2KAjfeS2xTSTN05sX1nw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dA2KAjfeS2xTSTN05sX1nw',
#    'review_count': 1125,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.048399475675, 'longitude': -118.23939954433},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '131 S Central Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90012',
# ...

# %%
pd.DataFrame(results_boba['businesses']).head()
# Out:
#                                  alias  \
# 0    twinkle-brown-sugar-los-angeles-2
# 1                 milk-t-los-angeles-3
# 2               bubble-u-los-angeles-2
# 3           pine-and-crane-los-angeles
# 4  little-fluffy-head-cafe-los-angeles
#
#                                           categories  \
# 0  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 1  [{'alias': 'foodtrucks', 'title': 'Food Trucks...
# 2  [{'alias': 'taiwanese', 'title': 'Taiwanese'},...
# 3  [{'alias': 'taiwanese', 'title': 'Taiwanese'},...
# 4  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 34.048399475675, 'longitude': -11...  (213) 626-8889
# 1  {'latitude': 34.0490233, 'longitude': -118.241...  (323) 884-1164
# 2  {'latitude': 34.0633996, 'longitude': -118.237...  (213) 628-3679
# 3  {'latitude': 34.0905963760163, 'longitude': -1...  (323) 668-1128
# ...

# %%
results_boba_flat = [flatten(d) for d in results_boba['businesses']]
data = pd.DataFrame(results_boba_flat).head()

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
data.to_csv("boba_LA.csv", encoding="utf-8", index=False)
